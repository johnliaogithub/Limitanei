# %% [markdown]
# ## Simulation experiment 1
# 2026-05-03
#
# Motivation:
# The M249 is the only gun that allows the drone to stabilize at an angle while continuously firing (approx. 48 degrees downwards).
#
# Objective:
# See whether or not an RL agent will control the drone (M249) to always to go that angle.
#
# Stats:
# M249_saw
# No wind
#
# Notes:
# ***I should probably remove some inputs from the environment that give it an unfair advantage (wind)***

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

from drone_sim.control.controller import quat_to_euler, wrap_pi
from drone_sim.rl.custom_envs import SingleTargetEnv
from drone_sim.rl.networks import SplitExtractor  # must be imported before PPO.load
from drone_sim.rl.callbacks import ShotStatsCallback
from drone_sim.sim import quat_to_rot

import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# %%
# Curriculum: start with a close target so target_rel_norm ~ [1,0,0] at spawn
# and the cosine aiming reward provides an immediate gradient. Scale up once
# the policy reliably shoots (ep_len stable at 400+, hits > 0 per episode).
TARGET_RADIUS = 5.0   # start at 5 m; increase to 20m, increase to 50, then 100, then 200 (because the distance is capped to 100, so see if the agent can come closer) once hitting consistently

vec_env = make_vec_env(
    lambda: SingleTargetEnv(
        control_level='thrust',
        target_radius=TARGET_RADIUS,
        action_pos_range_m=TARGET_RADIUS + 10.0,
        reward_cfg={
            "hit": 75.0,
            "aim": 0.03, # 0.03
            "miss_dist": 0.05, #0.05
            "ammo": 0.005,
            "stability": 0.01,
            "crash": 100.0,
        }
    ),
    n_envs=4,
)

# %%
# SplitExtractor must be imported (done above) so SB3 can reconstruct the policy.
# If loading a model saved before the SplitExtractor architecture was introduced,
# omit the custom_objects kwarg — SB3 will use the flat MLP stored in the zip.
model = PPO.load(
    "../experiment1/ppo_e1_5m_m249",
    env=vec_env,
    learning_rate=1e-4,
    ent_coef=0.01,
)

# %%
# --- Fire action cold-start fix ---
#
# Two things drive fire → never after training on ZeroTargetEnv:
#   1. action_net.bias[4]   ≈ -1.0  (constant offset)
#   2. action_net.weight[4, :]  negative weights  (state pushes it further down)
# Resetting the bias alone shifts the mean by +2, but the weight row can still
# dominate (e.g. weight contribution = -3 → net mean = -2, P(fire>0) ≈ 2%).
#
# Fix: zero the weight row so fire_mean = bias only (state-independent),
# then bias = +1.0 → P(fire > 0) = Φ(1/1.0) ≈ 84%.  Hover weights untouched.
with torch.no_grad():
    model.policy.action_net.weight.data[4, :] = 0.0   # remove state→fire coupling
    model.policy.action_net.bias.data[4]      = 1.0   # fire mean = +1
    model.policy.log_std.data[4]              = 0.0   # fire std = e^0 = 1.0

print(f"Fire weight norm (should be 0): {model.policy.action_net.weight.data[4].norm().item():.4f}")
print(f"Fire mean (bias):  {model.policy.action_net.bias.data[4].item():.2f}")
print(f"Fire log_std:      {model.policy.log_std.data[4].item():.2f}  →  std = {model.policy.log_std.data[4].exp().item():.2f}")
print(f"Thrust log_std:    {model.policy.log_std.data[0].item():.2f}  →  std = {model.policy.log_std.data[0].exp().item():.3f}")
print(f"P(fire > 0) ≈ 84.1%  (Φ(1) with mean=1, std=1)")
# Out:
# Fire weight norm (should be 0): 0.0000
# Fire mean (bias):  1.00
# Fire log_std:      0.00  →  std = 1.00
# Thrust log_std:    -1.85  →  std = 0.157
# P(fire > 0) ≈ 84.1%  (Φ(1) with mean=1, std=1)

# %%
model.learn(
    total_timesteps=100000,
    reset_num_timesteps=False,
    callback=ShotStatsCallback(print_freq=10),
)
model.save("ppo_e1_5m_m249")
# Out:
# [ep    10]  shots/ep=  44.8  hits/ep=6.50
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 424      |
# |    ep_rew_mean      | 398      |
# | shots/              |          |
# |    mean_hits_per_ep | 6.5      |
# |    mean_per_ep      | 44.8     |
# | time/               |          |
# |    fps              | 1852     |
# |    iterations       | 1        |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5185536  |
# ----------------------------------
# [ep    20]  shots/ep=  42.4  hits/ep=8.70
# [ep    30]  shots/ep=  43.7  hits/ep=9.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 442         |
# |    ep_rew_mean          | 464         |
# | shots/                  |             |
# |    mean_hits_per_ep     | 9           |
# |    mean_per_ep          | 43.7        |
# | time/                   |             |
# |    fps                  | 1029        |
# |    iterations           | 2           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 5193728     |
# | train/                  |             |
# |    approx_kl            | 0.017346015 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 327         |
# |    n_updates            | 6321        |
# |    policy_gradient_loss | 0.00184     |
# |    std                  | 0.598       |
# |    value_loss           | 588         |
# -----------------------------------------
# [ep    40]  shots/ep=  44.1  hits/ep=8.10
# [ep    50]  shots/ep=  47.9  hits/ep=11.60
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 464         |
# |    ep_rew_mean          | 563         |
# | shots/                  |             |
# |    mean_hits_per_ep     | 11.6        |
# |    mean_per_ep          | 47.9        |
# | time/                   |             |
# |    fps                  | 849         |
# |    iterations           | 3           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 5201920     |
# | train/                  |             |
# |    approx_kl            | 0.015826657 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 212         |
# |    n_updates            | 6331        |
# |    policy_gradient_loss | -0.00446    |
# |    std                  | 0.6         |
# |    value_loss           | 577         |
# -----------------------------------------
# [ep    60]  shots/ep=  44.5  hits/ep=12.30
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 472         |
# |    ep_rew_mean          | 677         |
# | shots/                  |             |
# |    mean_hits_per_ep     | 12.3        |
# |    mean_per_ep          | 44.5        |
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 4           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 5210112     |
# | train/                  |             |
# |    approx_kl            | 0.015074085 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 298         |
# |    n_updates            | 6341        |
# |    policy_gradient_loss | -0.00282    |
# |    std                  | 0.601       |
# |    value_loss           | 697         |
# -----------------------------------------
# [ep    70]  shots/ep=  44.6  hits/ep=13.50
# [ep    80]  shots/ep=  46.8  hits/ep=15.50
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 477         |
# |    ep_rew_mean          | 800         |
# | shots/                  |             |
# |    mean_hits_per_ep     | 15.5        |
# |    mean_per_ep          | 46.8        |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 5           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 5218304     |
# | train/                  |             |
# |    approx_kl            | 0.013056885 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.642       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 430         |
# |    n_updates            | 6351        |
# |    policy_gradient_loss | -0.000671   |
# |    std                  | 0.602       |
# |    value_loss           | 759         |
# -----------------------------------------
# [ep    90]  shots/ep=  45.6  hits/ep=17.30
# [ep   100]  shots/ep=  46.0  hits/ep=22.70
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 480        |
# |    ep_rew_mean          | 955        |
# | shots/                  |            |
# |    mean_hits_per_ep     | 22.7       |
# |    mean_per_ep          | 46         |
# | time/                   |            |
# |    fps                  | 732        |
# |    iterations           | 6          |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 5226496    |
# | train/                  |            |
# |    approx_kl            | 0.01344238 |
# |    clip_fraction        | 0.165      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.95      |
# |    explained_variance   | 0.637      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 288        |
# |    n_updates            | 6361       |
# |    policy_gradient_loss | -0.00603   |
# |    std                  | 0.6        |
# |    value_loss           | 882        |
# ----------------------------------------
# [ep   110]  shots/ep=  43.0  hits/ep=19.40
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 480         |
# |    ep_rew_mean          | 1.12e+03    |
# | shots/                  |             |
# |    mean_hits_per_ep     | 19.4        |
# |    mean_per_ep          | 43          |
# | time/                   |             |
# |    fps                  | 696         |
# |    iterations           | 7           |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 5234688     |
# | train/                  |             |
# |    approx_kl            | 0.012193963 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 318         |
# |    n_updates            | 6371        |
# |    policy_gradient_loss | -0.000708   |
# |    std                  | 0.602       |
# |    value_loss           | 875         |
# -----------------------------------------
# [ep   120]  shots/ep=  46.4  hits/ep=21.00
# [ep   130]  shots/ep=  46.6  hits/ep=22.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 484         |
# |    ep_rew_mean          | 1.27e+03    |
# | shots/                  |             |
# |    mean_hits_per_ep     | 22          |
# |    mean_per_ep          | 46.6        |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 8           |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 5242880     |
# | train/                  |             |
# |    approx_kl            | 0.015419072 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 457         |
# |    n_updates            | 6381        |
# |    policy_gradient_loss | 0.00202     |
# |    std                  | 0.603       |
# |    value_loss           | 842         |
# -----------------------------------------
# [ep   140]  shots/ep=  47.1  hits/ep=22.30
# [ep   150]  shots/ep=  46.4  hits/ep=23.70
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 488         |
# |    ep_rew_mean          | 1.43e+03    |
# | shots/                  |             |
# |    mean_hits_per_ep     | 23.7        |
# |    mean_per_ep          | 46.4        |
# | time/                   |             |
# |    fps                  | 710         |
# |    iterations           | 9           |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 5251072     |
# | train/                  |             |
# |    approx_kl            | 0.013291083 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 544         |
# |    n_updates            | 6391        |
# |    policy_gradient_loss | -0.000869   |
# |    std                  | 0.604       |
# |    value_loss           | 831         |
# -----------------------------------------
# [ep   160]  shots/ep=  46.8  hits/ep=25.20
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 496        |
# |    ep_rew_mean          | 1.57e+03   |
# | shots/                  |            |
# |    mean_hits_per_ep     | 25.2       |
# |    mean_per_ep          | 46.8       |
# | time/                   |            |
# |    fps                  | 710        |
# |    iterations           | 10         |
# |    time_elapsed         | 115        |
# |    total_timesteps      | 5259264    |
# | train/                  |            |
# |    approx_kl            | 0.01641461 |
# |    clip_fraction        | 0.182      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2         |
# |    explained_variance   | 0.729      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 469        |
# |    n_updates            | 6401       |
# |    policy_gradient_loss | -0.000297  |
# |    std                  | 0.606      |
# |    value_loss           | 813        |
# ----------------------------------------
# [ep   170]  shots/ep=  46.7  hits/ep=22.10
# [ep   180]  shots/ep=  46.5  hits/ep=23.10
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 496         |
# |    ep_rew_mean          | 1.66e+03    |
# | shots/                  |             |
# |    mean_hits_per_ep     | 23.1        |
# |    mean_per_ep          | 46.5        |
# | time/                   |             |
# |    fps                  | 716         |
# |    iterations           | 11          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 5267456     |
# | train/                  |             |
# |    approx_kl            | 0.015217244 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.734       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 317         |
# |    n_updates            | 6411        |
# |    policy_gradient_loss | -0.000959   |
# |    std                  | 0.605       |
# |    value_loss           | 762         |
# -----------------------------------------
# [ep   190]  shots/ep=  46.9  hits/ep=23.00
# [ep   200]  shots/ep=  45.9  hits/ep=23.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 496         |
# |    ep_rew_mean          | 1.69e+03    |
# | shots/                  |             |
# |    mean_hits_per_ep     | 23          |
# |    mean_per_ep          | 45.9        |
# | time/                   |             |
# |    fps                  | 718         |
# |    iterations           | 12          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 5275648     |
# | train/                  |             |
# |    approx_kl            | 0.014271333 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 677         |
# |    n_updates            | 6421        |
# |    policy_gradient_loss | -0.00282    |
# |    std                  | 0.605       |
# |    value_loss           | 857         |
# -----------------------------------------
# [ep   210]  shots/ep=  47.3  hits/ep=25.70
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 1.76e+03    |
# | shots/                  |             |
# |    mean_hits_per_ep     | 25.7        |
# |    mean_per_ep          | 47.3        |
# | time/                   |             |
# |    fps                  | 718         |
# |    iterations           | 13          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 5283840     |
# | train/                  |             |
# |    approx_kl            | 0.014641063 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.716       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 373         |
# |    n_updates            | 6431        |
# |    policy_gradient_loss | 0.000159    |
# |    std                  | 0.606       |
# |    value_loss           | 757         |
# -----------------------------------------

# %%
from drone_sim.rl.viz import visualize_episode

positions, rewards = visualize_episode(model, target_radius=TARGET_RADIUS, speed=1.0)
# Out:
# Episode ended at step 500  (truncated)
# Steps: 500 / 500  |  Total reward: 1130.0  |  Hits: 32

# %%
env = SingleTargetEnv(
    target_height=1.5,
    seed=42,
    max_episode_steps=1000,
    render_mode="human",
)

rewards = run_episode(env, model, render=True)
env.close()

plot_rewards(rewards)
# Out:
#  step    reward         cum   hits  ammo
# --------------------------------------------
#    20     +0.21       +5.68      0    26
#    24     +0.10       +6.26      0    25
# --------------------------------------------
# end: terminated=True truncated=False final cumulative reward = +6.26
# plot saved to pid_agent_reward.png
